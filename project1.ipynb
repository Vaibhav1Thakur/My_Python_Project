# %%
insertcard = input("Insert your card")

if insertcard == '1':
    a = int(input("Enter your pin"))


    if len(str(a)) != 4:
        print("Pin is incorrect . Please enter a four digit pin")

    else:
        if a == 1234:
            print("Pin verified successfully")
            b = input("select 1 for cash withdrawl \nSelect 2 for instant cash : \n ")

            if b == '1':
                c = int(input("Enter the amount(Multiple of 100). Max limit: 100 notes (Rs 10000):"))

                if c % 100 != 0:
                    print("Amount must be multiple of 100")

                elif c <= 10000:
                    print(" Please collect your cash")

                else:
                    print("print limit exceed. Please enter the amount with in the limit")

            elif b == '2':
                print("Instant cash of 2000rs is being dispensed. Please collect your cash")

            else:
                print("Invalid selection.")

        else:
            print("incorrect pin")

else:
    print("card not inseted. Please try again")
    
print("Thankyou")
# Out:
# Pin verified successfully
#  Please collect your cash
# Thankyou
